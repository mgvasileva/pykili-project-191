# %%
import random
import telebot

bot = telebot.TeleBot('1112308270:AAEqx7iRe19pelg-nqw7sK13WfkO-NZhMhY')

from telebot import types



@bot.message_handler(content_types=['text'])

def get_text_messages(message):

    if message.text == "Привет":

        bot.send_message(message.from_user.id, "Привет, выбери, куда ты хочешь пойти.")

        keyboard = types.InlineKeyboardMarkup()

        key_coffee = types.InlineKeyboardButton(text='Кофейня', callback_data='coffee')

        keyboard.add(key_coffee)

        key_rest = types.InlineKeyboardButton(text='Ресторан', callback_data='rest')

        keyboard.add(key_rest)

        key_fast = types.InlineKeyboardButton(text='Фастфуд', callback_data='fast')

        keyboard.add(key_fast)

    elif message.text == "/help":

        bot.send_message(message.from_user.id, "Напиши 'Привет' ")

    else:

        bot.send_message(message.from_user.id, "Неверный запрос. Напиши /help.")

@bot.callback_query_handler(func = lambda call: True)

def callback_worker(call):

    if call.data == "coffee": 
        
        place = call.data

        bot.send_message(message.from_user.id, "Выбери станцию метро")
        
        keyboard = types.InlineKeyboardMarkup()
        
        key_Tsvetnoy = types.InlineKeyboardButton(text='Цветной бульвар\Трубная', callback_data='Tsvetnoy')

        keyboard.add(key_Tsvetnoy

        key_Sukharevskaya = types.InlineKeyboardButton(text='Сухаревская', callback_data='Sukharevskaya')

        keyboard.add(key_Sukharevskaya)

        key_Turgenevskaya = types.InlineKeyboardButton(text='Тургеневская\Чистые пруды\Сретенский бульвар', callback_data='Turgenevskaya')

        keyboard.add(key_Turgenevskaya)

        key_Kuznetsky most = types.InlineKeyboardButton(text='Кузнецкий мост\Лубянка', callback_data='Kuznetsky most')

        keyboard.add(key_Kuznetsky most)

        key_China = types.InlineKeyboardButton(text='Китай-город', callback_data='China')

        keyboard.add(key_China)

        key_Tretyakovsky = types.InlineKeyboardButton(text='Третьяковская\Новокузнецкая', callback_data='Tretyakovsky')

        keyboard.add(key_Tretyakovsky)

        key_Borovitskaya = types.InlineKeyboardButton(text='Боровицкая\Александровский сад\Арбатская синяя\Библиотека имени Ленина', callback_data='Borovitskaya')

        keyboard.add(key_Borovitskaya)

        key_Kropotkinskaya = types.InlineKeyboardButton(text='Кропоткинская', callback_data='Kropotkinskaya')

        keyboard.add(key_Kropotkinskaya)

        key_Arbatblue = types.InlineKeyboardButton(text='Арбатская голубая', callback_data='Arbatblue')

        keyboard.add(key_Arbatblue)

        key_Smolensk = types.InlineKeyboardButton(text='Смоленская', callback_data='Smolensk')

        keyboard.add(key_Smolensk)

        key_Tverskaya = types.InlineKeyboardButton(text='Тверская\Пушкинская\Чеховская', callback_data='Tverskaya')

        keyboard.add(key_Tverskaya)

        key_Mayakovskaya = types.InlineKeyboardButton(text='Маяковская', callback_data='Mayakovskaya')

        keyboard.add(key_Mayakovskaya)

        key_Krasnopresnenskaya = types.InlineKeyboardButton(text='Краснопресненская\Баррикадная', callback_data='Krasnopresnenskaya')

        keyboard.add(key_Sukharevskaya)

        key_Belarusian = types.InlineKeyboardButton(text='Белорусская', callback_data='Belarusian')

        keyboard.add(key_Belarusian)

        key_Mendeleevskaya = types.InlineKeyboardButton(text='Менделеевская\Новослободская', callback_data='Mendeleevskaya')

        keyboard.add(key_Mendeleevskaya)

        key_prospect = types.InlineKeyboardButton(text='Проспект Мира', callback_data='prospect')

        keyboard.add(key_prospect)

        key_Komsomol = types.InlineKeyboardButton(text='Комсомольская', callback_data='Komsomol')

        keyboard.add(key_Komsomol)

        key_Paveletskaya = types.InlineKeyboardButton(text='Павелецкая', callback_data='Paveletskaya')

        keyboard.add(key_Paveletskaya)

        key_Dobryninskaya = types.InlineKeyboardButton(text='Добрынинская\Серпуховская', callback_data='Dobryninskaya')

        keyboard.add(key_Sukharevskaya)

        key_October = types.InlineKeyboardButton(text='Октябрьская', callback_data='October')

        keyboard.add(key_October)

        key_Kiev = types.InlineKeyboardButton(text='Киевская', callback_data='Kiev')

        keyboard.add(key_Kiev)

        key_Marxist = types.InlineKeyboardButton(text='Марксистская\Таганская', callback_data='Marxist')

        keyboard.add(key_Marxist)
                    
        v        if call.data == 'Tsvetnoy':
            
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Sukharevskaya':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Turgenevskaya':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Kuznetsky most':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Tretyakovsky':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Polyanka':
                    station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Borovitskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Kropotkinskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Arbat blue':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Smolensk':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Tverskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Mayakovskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Krasnopresnenskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Belarusian':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)

        if call.data == 'Mendeleevskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
              
        if call.data == 'prospect':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Komsomol':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Paveletskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Dobryninskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'October':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Kiev':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Marxist':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'China':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
                     
    else if call.data == "rest": 
        
        if call.data == 'Tsvetnoy':
            
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Sukharevskaya':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Turgenevskaya':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Kuznetsky most':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Tretyakovsky':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Polyanka':
                    station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Borovitskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Kropotkinskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Arbat blue':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Smolensk':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Tverskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Mayakovskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Krasnopresnenskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Belarusian':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)

        if call.data == 'Mendeleevskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
              
        if call.data == 'prospect':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Komsomol':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Paveletskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Dobryninskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'October':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Kiev':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Marxist':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'China':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
    
    else if call.data == "fast":
        
                if call.data == 'Tsvetnoy':
            
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Sukharevskaya':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Turgenevskaya':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Kuznetsky most':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Tretyakovsky':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Polyanka':
                    station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Borovitskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Kropotkinskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Arbat blue':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Smolensk':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Tverskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Mayakovskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Krasnopresnenskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Belarusian':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)

        if call.data == 'Mendeleevskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
              
        if call.data == 'prospect':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Komsomol':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Paveletskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Dobryninskaya':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'October':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Kiev':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'Marxist':
                     station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)
            
        if call.data == 'China':
        
            station = call.data
                     
            bot.send_message(message.from_user.id, "Какую сумму Вы хотите потратить?")
                     
            keyboard = types.InlineKeyboardMarkup()

            key_one = types.InlineKeyboardButton(text='$', callback_data='$')

            keyboard.add(key_one)

            key_two = types.InlineKeyboardButton(text='$$', callback_data='$$')

            keyboard.add(key_two)

            key_three = types.InlineKeyboardButton(text='$$$', callback_data='$$$')

            keyboard.add(key_three)
                     
            if call.data == '$':
                     
                price = call.data
                     
                with open('one.txt', encoding='utf-8') as f:
                     
                    text = f.read()
                     
                lines = text.split('\n')
                     
                for line in lines:
                     
                     parts = line.split(';')
                     
                     if parts[-1] == price and parts[-2] == station:
                         
                         msg = parts[0]
                
                bot.send_message(call.message.chat.id, msg)

bot.polling(none_stop=True, interval=0)
